# %% [markdown]
# # Использование VSSD
#
# ### Задача:
# [задача](../../tasks/hometask_23.ipynb)

# %% [markdown]
# Для этой задачи будем использовать датасет `SidSet` - датасет для задачи распознавания ai редактирования картинок.
#
# В качестве модели возьмем модель задачи `vssd`, а для апсемплера - архитектуру `upernet`.
#
# Для запуска кода обучения нужно выполнить команду:
#
# - для задачи классификации изображений с использованием VSSD:
# ```bash
# python main.py --cn image_class_vssd
# ```
# - для задачи сегментации изображений с использованием VSSD:
# ```bash
# python main.py --cn image_segmentation_vssd
# ```

# %% [markdown]
# Получим следующие логи:
#
# - для задачи классификации изображений с использованием VSSD:
# ```plaintext
# 2025-11-26 18:57:48,190 -     epoch          : 1
# 2025-11-26 18:57:48,192 -     loss           : 0.6514965176582337
# 2025-11-26 18:57:48,198 -     grad_norm      : 0.9999998557567596
# 2025-11-26 18:57:48,204 -     val_loss       : 0.6426501622051001
# 2025-11-26 18:57:48,209 -     val_Acc_Top_1  : 62.2265625
# 2025-11-26 18:57:48,214 -     val_Acc_Top_5  : 100.0
# 2025-11-26 19:09:44,446 -     epoch          : 2
# 2025-11-26 19:09:44,449 -     loss           : 0.6668774259090423
# 2025-11-26 19:09:44,455 -     grad_norm      : 0.9999999010562897
# 2025-11-26 19:09:44,461 -     val_loss       : 0.8690119515359401
# 2025-11-26 19:09:44,467 -     val_Acc_Top_1  : 54.7578125
# 2025-11-26 19:09:44,472 -     val_Acc_Top_5  : 100.0
# 2025-11-26 19:21:34,581 -     epoch          : 3
# 2025-11-26 19:21:34,583 -     loss           : 0.5888324570655823
# 2025-11-26 19:21:34,590 -     grad_norm      : 0.9999998199939728
# 2025-11-26 19:21:34,596 -     val_loss       : 0.6841076068580151
# 2025-11-26 19:21:34,602 -     val_Acc_Top_1  : 61.96875
# 2025-11-26 19:21:34,607 -     val_Acc_Top_5  : 100.0
# 2025-11-26 19:33:24,793 -     epoch          : 4
# 2025-11-26 19:33:24,796 -     loss           : 0.6098027122020722
# 2025-11-26 19:33:24,802 -     grad_norm      : 0.9999998497962952
# 2025-11-26 19:33:24,808 -     val_loss       : 0.7053327907249332
# 2025-11-26 19:33:24,813 -     val_Acc_Top_1  : 61.78125
# 2025-11-26 19:33:24,819 -     val_Acc_Top_5  : 100.0
# 2025-11-26 19:45:14,770 -     epoch          : 5
# 2025-11-26 19:45:14,772 -     loss           : 0.6681563144922257
# 2025-11-26 19:45:14,778 -     grad_norm      : 0.9999999582767487
# 2025-11-26 19:45:14,784 -     val_loss       : 0.7189397369325161
# 2025-11-26 19:45:14,790 -     val_Acc_Top_1  : 59.8359375
# 2025-11-26 19:45:14,795 -     val_Acc_Top_5  : 100.0
# 2025-11-26 19:57:05,080 -     epoch          : 6
# 2025-11-26 19:57:05,082 -     loss           : 0.6520238071680069
# 2025-11-26 19:57:05,089 -     grad_norm      : 0.9999998927116394
# 2025-11-26 19:57:05,094 -     val_loss       : 0.7020214030146599
# 2025-11-26 19:57:05,100 -     val_Acc_Top_1  : 62.859375
# 2025-11-26 19:57:05,106 -     val_Acc_Top_5  : 100.0
# 2025-11-26 20:09:01,094 -     epoch          : 7
# 2025-11-26 20:09:01,096 -     loss           : 0.5793359291553497
# 2025-11-26 20:09:01,101 -     grad_norm      : 0.9999998700618744
# 2025-11-26 20:09:01,106 -     val_loss       : 0.6256604188121855
# 2025-11-26 20:09:01,110 -     val_Acc_Top_1  : 65.5859375
# 2025-11-26 20:09:01,115 -     val_Acc_Top_5  : 100.0
# 2025-11-26 20:20:57,458 -     epoch          : 8
# 2025-11-26 20:20:57,460 -     loss           : 0.600047796368599
# 2025-11-26 20:20:57,466 -     grad_norm      : 0.9999998521804809
# 2025-11-26 20:20:57,471 -     val_loss       : 0.6674441680125892
# 2025-11-26 20:20:57,478 -     val_Acc_Top_1  : 63.8984375
# 2025-11-26 20:20:57,484 -     val_Acc_Top_5  : 100.0
# 2025-11-26 20:32:48,097 -     epoch          : 9
# 2025-11-26 20:32:48,099 -     loss           : 0.6880411821603775
# 2025-11-26 20:32:48,105 -     grad_norm      : 0.9999999189376831
# 2025-11-26 20:32:48,111 -     val_loss       : 0.6452088608779013
# 2025-11-26 20:32:48,118 -     val_Acc_Top_1  : 62.96875
# 2025-11-26 20:32:48,124 -     val_Acc_Top_5  : 100.0
# 2025-11-26 20:44:37,928 -     epoch          : 10
# 2025-11-26 20:44:37,930 -     loss           : 0.6125799977779388
# 2025-11-26 20:44:37,936 -     grad_norm      : 0.9999999213218689
# 2025-11-26 20:44:37,942 -     val_loss       : 0.6265415159612894
# 2025-11-26 20:44:37,947 -     val_Acc_Top_1  : 65.3203125
# 2025-11-26 20:44:37,952 -     val_Acc_Top_5  : 100.0
# 2025-11-26 20:56:27,953 -     epoch          : 11
# 2025-11-26 20:56:27,955 -     loss           : 0.5785039728879928
# 2025-11-26 20:56:27,962 -     grad_norm      : 0.9999998927116394
# 2025-11-26 20:56:27,967 -     val_loss       : 0.6926827524788678
# 2025-11-26 20:56:27,973 -     val_Acc_Top_1  : 63.0
# 2025-11-26 20:56:27,979 -     val_Acc_Top_5  : 100.0
# 2025-11-26 21:08:18,321 -     epoch          : 12
# 2025-11-26 21:08:18,323 -     loss           : 0.5512845408916474
# 2025-11-26 21:08:18,329 -     grad_norm      : 0.9999998915195465
# 2025-11-26 21:08:18,335 -     val_loss       : 0.6586429085209966
# 2025-11-26 21:08:18,343 -     val_Acc_Top_1  : 64.28125
# 2025-11-26 21:08:18,348 -     val_Acc_Top_5  : 100.0
# 2025-11-26 21:20:08,500 -     epoch          : 13
# 2025-11-26 21:20:08,503 -     loss           : 0.6158181667327881
# 2025-11-26 21:20:08,509 -     grad_norm      : 0.9999999570846557
# 2025-11-26 21:20:08,515 -     val_loss       : 0.6702243542298675
# 2025-11-26 21:20:08,522 -     val_Acc_Top_1  : 63.875
# 2025-11-26 21:20:08,527 -     val_Acc_Top_5  : 100.0
# 2025-11-26 21:31:58,319 -     epoch          : 14
# 2025-11-26 21:31:58,322 -     loss           : 0.5219655966758728
# 2025-11-26 21:31:58,328 -     grad_norm      : 0.999999862909317
# 2025-11-26 21:31:58,333 -     val_loss       : 0.6232937027141452
# 2025-11-26 21:31:58,339 -     val_Acc_Top_1  : 66.28125
# 2025-11-26 21:31:58,344 -     val_Acc_Top_5  : 100.0
# 2025-11-26 21:43:55,097 -     epoch          : 15
# 2025-11-26 21:43:55,099 -     loss           : 0.5736436396837234
# 2025-11-26 21:43:55,106 -     grad_norm      : 0.9999998426437378
# 2025-11-26 21:43:55,112 -     val_loss       : 0.6191847259178758
# 2025-11-26 21:43:55,117 -     val_Acc_Top_1  : 64.7109375
# 2025-11-26 21:43:55,123 -     val_Acc_Top_5  : 100.0
# 2025-11-26 21:55:46,223 -     epoch          : 16
# 2025-11-26 21:55:46,225 -     loss           : 0.5199606573581695
# 2025-11-26 21:55:46,231 -     grad_norm      : 0.9891870391368865
# 2025-11-26 21:55:46,237 -     val_loss       : 0.6154073701612651
# 2025-11-26 21:55:46,242 -     val_Acc_Top_1  : 65.328125
# 2025-11-26 21:55:46,248 -     val_Acc_Top_5  : 100.0
# 2025-11-26 22:07:36,686 -     epoch          : 17
# 2025-11-26 22:07:36,688 -     loss           : 0.5489847671985626
# 2025-11-26 22:07:36,694 -     grad_norm      : 0.9999998605251312
# 2025-11-26 22:07:36,699 -     val_loss       : 0.6508991633728146
# 2025-11-26 22:07:36,705 -     val_Acc_Top_1  : 65.84375
# 2025-11-26 22:07:36,710 -     val_Acc_Top_5  : 100.0
# 2025-11-26 22:19:27,036 -     epoch          : 18
# 2025-11-26 22:19:27,038 -     loss           : 0.607934273481369
# 2025-11-26 22:19:27,045 -     grad_norm      : 0.9999999392032624
# 2025-11-26 22:19:27,050 -     val_loss       : 0.6297877962887287
# 2025-11-26 22:19:27,056 -     val_Acc_Top_1  : 64.8125
# 2025-11-26 22:19:27,062 -     val_Acc_Top_5  : 100.0
# 2025-11-26 22:31:17,054 -     epoch          : 19
# 2025-11-26 22:31:17,056 -     loss           : 0.5453120356798172
# 2025-11-26 22:31:17,062 -     grad_norm      : 0.9999998414516449
# 2025-11-26 22:31:17,067 -     val_loss       : 0.6334747975319623
# 2025-11-26 22:31:17,073 -     val_Acc_Top_1  : 65.609375
# 2025-11-26 22:31:17,079 -     val_Acc_Top_5  : 100.0
# 2025-11-26 22:43:06,898 -     epoch          : 20
# 2025-11-26 22:43:06,900 -     loss           : 0.5697141191363335
# 2025-11-26 22:43:06,909 -     grad_norm      : 0.9999998664855957
# 2025-11-26 22:43:06,915 -     val_loss       : 0.5556755361519754
# 2025-11-26 22:43:06,921 -     val_Acc_Top_1  : 68.4453125
# 2025-11-26 22:43:06,927 -     val_Acc_Top_5  : 100.0
# 2025-11-26 22:55:04,011 -     epoch          : 21
# 2025-11-26 22:55:04,014 -     loss           : 0.50561179459095
# 2025-11-26 22:55:04,020 -     grad_norm      : 0.9999997174739838
# 2025-11-26 22:55:04,026 -     val_loss       : 0.6837957294285297
# 2025-11-26 22:55:04,032 -     val_Acc_Top_1  : 65.2578125
# 2025-11-26 22:55:04,044 -     val_Acc_Top_5  : 100.0
# 2025-11-26 23:06:53,838 -     epoch          : 22
# 2025-11-26 23:06:53,840 -     loss           : 0.5599117231369019
# 2025-11-26 23:06:53,846 -     grad_norm      : 0.9951018464565277
# 2025-11-26 23:06:53,851 -     val_loss       : 0.5949261708930135
# 2025-11-26 23:06:53,857 -     val_Acc_Top_1  : 68.3828125
# 2025-11-26 23:06:53,862 -     val_Acc_Top_5  : 100.0
# 2025-11-26 23:18:43,760 -     epoch          : 23
# 2025-11-26 23:18:43,762 -     loss           : 0.5251720213890075
# 2025-11-26 23:18:43,768 -     grad_norm      : 0.9999998044967652
# 2025-11-26 23:18:43,775 -     val_loss       : 0.6035145428404212
# 2025-11-26 23:18:43,780 -     val_Acc_Top_1  : 69.015625
# 2025-11-26 23:18:43,785 -     val_Acc_Top_5  : 100.0
# 2025-11-26 23:30:39,858 -     epoch          : 24
# 2025-11-26 23:30:39,861 -     loss           : 0.5414617758989334
# 2025-11-26 23:30:39,867 -     grad_norm      : 0.9999997985363006
# 2025-11-26 23:30:39,872 -     val_loss       : 0.623032100778073
# 2025-11-26 23:30:39,877 -     val_Acc_Top_1  : 68.1015625
# 2025-11-26 23:30:39,885 -     val_Acc_Top_5  : 100.0
# 2025-11-26 23:42:29,747 -     epoch          : 25
# 2025-11-26 23:42:29,749 -     loss           : 0.5130720007419586
# 2025-11-26 23:42:29,754 -     grad_norm      : 0.9999997961521149
# 2025-11-26 23:42:29,758 -     val_loss       : 0.6121329719014466
# 2025-11-26 23:42:29,762 -     val_Acc_Top_1  : 70.125
# 2025-11-26 23:42:29,766 -     val_Acc_Top_5  : 100.0
# 2025-11-26 23:54:26,438 -     epoch          : 26
# 2025-11-26 23:54:26,440 -     loss           : 0.5322251707315445
# 2025-11-26 23:54:26,446 -     grad_norm      : 0.9999998342990876
# 2025-11-26 23:54:26,451 -     val_loss       : 0.6075131499581039
# 2025-11-26 23:54:26,456 -     val_Acc_Top_1  : 67.9921875
# 2025-11-26 23:54:26,461 -     val_Acc_Top_5  : 100.0
# 2025-11-27 00:06:18,752 -     epoch          : 27
# 2025-11-27 00:06:18,755 -     loss           : 0.5288046973943711
# 2025-11-27 00:06:18,761 -     grad_norm      : 0.9999998247623444
# 2025-11-27 00:06:18,767 -     val_loss       : 0.6179228207841515
# 2025-11-27 00:06:18,772 -     val_Acc_Top_1  : 68.2734375
# 2025-11-27 00:06:18,777 -     val_Acc_Top_5  : 100.0
# 2025-11-27 00:18:09,217 -     epoch          : 28
# 2025-11-27 00:18:09,220 -     loss           : 0.4804365658760071
# 2025-11-27 00:18:09,225 -     grad_norm      : 0.9999998164176941
# 2025-11-27 00:18:09,231 -     val_loss       : 0.6074655834492296
# 2025-11-27 00:18:09,236 -     val_Acc_Top_1  : 70.390625
# 2025-11-27 00:18:09,241 -     val_Acc_Top_5  : 100.0
# 2025-11-27 00:30:06,015 -     epoch          : 29
# 2025-11-27 00:30:06,018 -     loss           : 0.5335236668586731
# 2025-11-27 00:30:06,023 -     grad_norm      : 0.9999998533725738
# 2025-11-27 00:30:06,030 -     val_loss       : 0.6402328064851462
# 2025-11-27 00:30:06,036 -     val_Acc_Top_1  : 69.515625
# 2025-11-27 00:30:06,044 -     val_Acc_Top_5  : 100.0
# 2025-11-27 00:41:55,876 -     epoch          : 30
# 2025-11-27 00:41:55,879 -     loss           : 0.5401290589571
# 2025-11-27 00:41:55,885 -     grad_norm      : 0.9999997639656066
# 2025-11-27 00:41:55,890 -     val_loss       : 0.6140333391726017
# 2025-11-27 00:41:55,895 -     val_Acc_Top_1  : 69.4296875
# 2025-11-27 00:41:55,900 -     val_Acc_Top_5  : 100.0
# 2025-11-27 00:53:45,997 -     epoch          : 31
# 2025-11-27 00:53:46,000 -     loss           : 0.5049253517389297
# 2025-11-27 00:53:46,006 -     grad_norm      : 0.9999998092651368
# 2025-11-27 00:53:46,012 -     val_loss       : 0.6081194815970957
# 2025-11-27 00:53:46,018 -     val_Acc_Top_1  : 71.375
# 2025-11-27 00:53:46,024 -     val_Acc_Top_5  : 100.0
# 2025-11-27 01:05:42,469 -     epoch          : 32
# 2025-11-27 01:05:42,472 -     loss           : 0.47602837562561034
# 2025-11-27 01:05:42,480 -     grad_norm      : 0.9999997448921204
# 2025-11-27 01:05:42,486 -     val_loss       : 0.6154755908809603
# 2025-11-27 01:05:42,492 -     val_Acc_Top_1  : 71.296875
# 2025-11-27 01:05:42,497 -     val_Acc_Top_5  : 100.0
# 2025-11-27 01:17:32,195 -     epoch          : 33
# 2025-11-27 01:17:32,197 -     loss           : 0.46438268542289735
# 2025-11-27 01:17:32,204 -     grad_norm      : 0.9999997675418854
# 2025-11-27 01:17:32,210 -     val_loss       : 0.5802558518759906
# 2025-11-27 01:17:32,216 -     val_Acc_Top_1  : 73.203125
# 2025-11-27 01:17:32,221 -     val_Acc_Top_5  : 100.0
# 2025-11-27 01:29:28,350 -     epoch          : 34
# 2025-11-27 01:29:28,353 -     loss           : 0.4728477293252945
# 2025-11-27 01:29:28,359 -     grad_norm      : 0.9999997568130493
# 2025-11-27 01:29:28,365 -     val_loss       : 0.5954522771388292
# 2025-11-27 01:29:28,370 -     val_Acc_Top_1  : 73.5234375
# 2025-11-27 01:29:28,375 -     val_Acc_Top_5  : 100.0
# 2025-11-27 01:41:24,470 -     epoch          : 35
# 2025-11-27 01:41:24,472 -     loss           : 0.4705073794722557
# 2025-11-27 01:41:24,479 -     grad_norm      : 0.999999715089798
# 2025-11-27 01:41:24,484 -     val_loss       : 0.559672207068652
# 2025-11-27 01:41:24,489 -     val_Acc_Top_1  : 73.640625
# 2025-11-27 01:41:24,494 -     val_Acc_Top_5  : 100.0
# 2025-11-27 01:53:20,786 -     epoch          : 36
# 2025-11-27 01:53:20,788 -     loss           : 0.4605942237377167
# 2025-11-27 01:53:20,794 -     grad_norm      : 0.998577412366867
# 2025-11-27 01:53:20,799 -     val_loss       : 0.5783401158824563
# 2025-11-27 01:53:20,804 -     val_Acc_Top_1  : 73.125
# 2025-11-27 01:53:20,809 -     val_Acc_Top_5  : 100.0
# 2025-11-27 02:05:10,472 -     epoch          : 37
# 2025-11-27 02:05:10,474 -     loss           : 0.4779755002260208
# 2025-11-27 02:05:10,480 -     grad_norm      : 0.9999996960163117
# 2025-11-27 02:05:10,485 -     val_loss       : 0.5760580629296601
# 2025-11-27 02:05:10,490 -     val_Acc_Top_1  : 73.9140625
# 2025-11-27 02:05:10,496 -     val_Acc_Top_5  : 100.0
# 2025-11-27 02:17:06,510 -     epoch          : 38
# 2025-11-27 02:17:06,513 -     loss           : 0.4392069166898727
# 2025-11-27 02:17:06,519 -     grad_norm      : 0.9999996757507325
# 2025-11-27 02:17:06,526 -     val_loss       : 0.5763915386795998
# 2025-11-27 02:17:06,532 -     val_Acc_Top_1  : 74.5546875
# 2025-11-27 02:17:06,538 -     val_Acc_Top_5  : 100.0
# 2025-11-27 02:29:03,029 -     epoch          : 39
# 2025-11-27 02:29:03,031 -     loss           : 0.4603418493270874
# 2025-11-27 02:29:03,038 -     grad_norm      : 0.9999997580051422
# 2025-11-27 02:29:03,043 -     val_loss       : 0.6558167663402855
# 2025-11-27 02:29:03,049 -     val_Acc_Top_1  : 72.828125
# 2025-11-27 02:29:03,054 -     val_Acc_Top_5  : 100.0
# 2025-11-27 02:40:52,968 -     epoch          : 40
# 2025-11-27 02:40:52,970 -     loss           : 0.43487239867448807
# 2025-11-27 02:40:52,976 -     grad_norm      : 0.9999997127056122
# 2025-11-27 02:40:52,981 -     val_loss       : 0.5560365348123014
# 2025-11-27 02:40:52,987 -     val_Acc_Top_1  : 74.71875
# 2025-11-27 02:40:52,992 -     val_Acc_Top_5  : 100.0
# 2025-11-27 02:52:48,651 -     epoch          : 41
# 2025-11-27 02:52:48,653 -     loss           : 0.4196739879250526
# 2025-11-27 02:52:48,660 -     grad_norm      : 0.9999997401237488
# 2025-11-27 02:52:48,666 -     val_loss       : 0.5711934584006667
# 2025-11-27 02:52:48,672 -     val_Acc_Top_1  : 75.53125
# 2025-11-27 02:52:48,678 -     val_Acc_Top_5  : 100.0
# 2025-11-27 03:04:45,095 -     epoch          : 42
# 2025-11-27 03:04:45,097 -     loss           : 0.4365574184060097
# 2025-11-27 03:04:45,103 -     grad_norm      : 0.9999997639656066
# 2025-11-27 03:04:45,108 -     val_loss       : 0.5819282253459096
# 2025-11-27 03:04:45,113 -     val_Acc_Top_1  : 75.4921875
# 2025-11-27 03:04:45,118 -     val_Acc_Top_5  : 100.0
# 2025-11-27 03:16:34,900 -     epoch          : 43
# 2025-11-27 03:16:34,902 -     loss           : 0.4648781770467758
# 2025-11-27 03:16:34,908 -     grad_norm      : 0.9999997746944428
# 2025-11-27 03:16:34,914 -     val_loss       : 0.5697740375809371
# 2025-11-27 03:16:34,920 -     val_Acc_Top_1  : 75.7265625
# 2025-11-27 03:16:34,928 -     val_Acc_Top_5  : 100.0
# 2025-11-27 03:28:31,154 -     epoch          : 44
# 2025-11-27 03:28:31,156 -     loss           : 0.46541312396526335
# 2025-11-27 03:28:31,162 -     grad_norm      : 0.9999996614456177
# 2025-11-27 03:28:31,170 -     val_loss       : 0.60159169472754
# 2025-11-27 03:28:31,176 -     val_Acc_Top_1  : 75.6875
# 2025-11-27 03:28:31,182 -     val_Acc_Top_5  : 100.0
# 2025-11-27 03:40:21,071 -     epoch          : 45
# 2025-11-27 03:40:21,074 -     loss           : 0.4513067597150803
# 2025-11-27 03:40:21,081 -     grad_norm      : 0.9999997115135193
# 2025-11-27 03:40:21,087 -     val_loss       : 0.6474890325777233
# 2025-11-27 03:40:21,093 -     val_Acc_Top_1  : 73.8125
# 2025-11-27 03:40:21,098 -     val_Acc_Top_5  : 100.0
# 2025-11-27 03:52:11,128 -     epoch          : 46
# 2025-11-27 03:52:11,130 -     loss           : 0.4263090828061104
# 2025-11-27 03:52:11,137 -     grad_norm      : 0.9999996662139893
# 2025-11-27 03:52:11,144 -     val_loss       : 0.5472601160220801
# 2025-11-27 03:52:11,150 -     val_Acc_Top_1  : 75.8828125
# 2025-11-27 03:52:11,156 -     val_Acc_Top_5  : 100.0
# 2025-11-27 04:04:07,796 -     epoch          : 47
# 2025-11-27 04:04:07,798 -     loss           : 0.4318057692050934
# 2025-11-27 04:04:07,805 -     grad_norm      : 0.9964332795143127
# 2025-11-27 04:04:07,813 -     val_loss       : 0.5418437533825636
# 2025-11-27 04:04:07,821 -     val_Acc_Top_1  : 76.984375
# 2025-11-27 04:04:07,827 -     val_Acc_Top_5  : 100.0
# 2025-11-27 04:16:04,422 -     epoch          : 48
# 2025-11-27 04:16:04,424 -     loss           : 0.42768859207630155
# 2025-11-27 04:16:04,430 -     grad_norm      : 0.9944351100921631
# 2025-11-27 04:16:04,435 -     val_loss       : 0.5541053638793528
# 2025-11-27 04:16:04,442 -     val_Acc_Top_1  : 76.625
# 2025-11-27 04:16:04,447 -     val_Acc_Top_5  : 100.0
# 2025-11-27 04:27:55,193 -     epoch          : 49
# 2025-11-27 04:27:55,196 -     loss           : 0.42205237060785294
# 2025-11-27 04:27:55,203 -     grad_norm      : 0.9999996650218964
# 2025-11-27 04:27:55,208 -     val_loss       : 0.5585413271561265
# 2025-11-27 04:27:55,216 -     val_Acc_Top_1  : 77.40625
# 2025-11-27 04:27:55,221 -     val_Acc_Top_5  : 100.0
# 2025-11-27 04:39:51,409 -     epoch          : 50
# 2025-11-27 04:39:51,411 -     loss           : 0.40681286215782164
# 2025-11-27 04:39:51,417 -     grad_norm      : 0.9999996852874756
# 2025-11-27 04:39:51,424 -     val_loss       : 0.573403654191643
# 2025-11-27 04:39:51,429 -     val_Acc_Top_1  : 77.2578125
# 2025-11-27 04:39:51,435 -     val_Acc_Top_5  : 100.0
# ```
# - для задачи сегментации изображений с использованием VSSD:
# ```plaintext
# 2025-11-27 16:55:32,599 -     epoch          : 1
# 2025-11-27 16:55:32,602 -     loss           : 1.1905714464187622
# 2025-11-27 16:55:32,603 -     grad_norm      : 0.9545724135637284
# 2025-11-27 16:55:32,603 -     val_loss       : 1.2074463748931885
# 2025-11-27 16:55:32,603 -     val_AP_50      : 0.0015
# 2025-11-27 16:55:32,604 -     val_AP_75      : 0.0
# 2025-11-27 16:55:32,604 -     val_IOU        : 0.012251084877736724
# 2025-11-27 17:09:59,851 -     epoch          : 2
# 2025-11-27 17:09:59,853 -     loss           : 1.2130110847949982
# 2025-11-27 17:09:59,854 -     grad_norm      : 0.9313523697853089
# 2025-11-27 17:09:59,854 -     val_loss       : 1.1283665418624877
# 2025-11-27 17:09:59,855 -     val_AP_50      : 0.0398
# 2025-11-27 17:09:59,855 -     val_AP_75      : 0.0022
# 2025-11-27 17:09:59,855 -     val_IOU        : 0.12930022175908087
# 2025-11-27 17:24:29,494 -     epoch          : 3
# 2025-11-27 17:24:29,497 -     loss           : 1.1697619485855102
# 2025-11-27 17:24:29,498 -     grad_norm      : 0.9518287777900696
# 2025-11-27 17:24:29,498 -     val_loss       : 1.1278015043258667
# 2025-11-27 17:24:29,498 -     val_AP_50      : 0.0228
# 2025-11-27 17:24:29,499 -     val_AP_75      : 0.0022
# 2025-11-27 17:24:29,499 -     val_IOU        : 0.07172347696349025
# 2025-11-27 17:38:51,761 -     epoch          : 4
# 2025-11-27 17:38:51,767 -     loss           : 1.1496221435070038
# 2025-11-27 17:38:51,768 -     grad_norm      : 0.9961512780189514
# 2025-11-27 17:38:51,768 -     val_loss       : 1.138990966796875
# 2025-11-27 17:38:51,769 -     val_AP_50      : 0.0239
# 2025-11-27 17:38:51,769 -     val_AP_75      : 0.0009
# 2025-11-27 17:38:51,769 -     val_IOU        : 0.08243096464201807
# 2025-11-27 17:53:14,137 -     epoch          : 5
# 2025-11-27 17:53:14,140 -     loss           : 1.0958609867095948
# 2025-11-27 17:53:14,141 -     grad_norm      : 0.9842054283618927
# 2025-11-27 17:53:14,142 -     val_loss       : 1.1278461831092834
# 2025-11-27 17:53:14,142 -     val_AP_50      : 0.0306
# 2025-11-27 17:53:14,143 -     val_AP_75      : 0.002
# 2025-11-27 17:53:14,143 -     val_IOU        : 0.08582345727587107
# 2025-11-27 18:07:36,800 -     epoch          : 6
# 2025-11-27 18:07:36,802 -     loss           : 1.0817119014263152
# 2025-11-27 18:07:36,803 -     grad_norm      : 0.9977192831039429
# 2025-11-27 18:07:36,803 -     val_loss       : 1.1202903675079345
# 2025-11-27 18:07:36,804 -     val_AP_50      : 0.0724
# 2025-11-27 18:07:36,804 -     val_AP_75      : 0.0066
# 2025-11-27 18:07:36,805 -     val_IOU        : 0.15677863592505456
# 2025-11-27 18:22:06,205 -     epoch          : 7
# 2025-11-27 18:22:06,208 -     loss           : 1.0457924509048462
# 2025-11-27 18:22:06,208 -     grad_norm      : 0.9847773230075836
# 2025-11-27 18:22:06,209 -     val_loss       : 1.1911023487091064
# 2025-11-27 18:22:06,209 -     val_AP_50      : 0.0211
# 2025-11-27 18:22:06,210 -     val_AP_75      : 0.0016
# 2025-11-27 18:22:06,210 -     val_IOU        : 0.058448916572305346
# 2025-11-27 18:36:27,919 -     epoch          : 8
# 2025-11-27 18:36:27,921 -     loss           : 1.0535052335262298
# 2025-11-27 18:36:27,924 -     grad_norm      : 0.993766063451767
# 2025-11-27 18:36:27,924 -     val_loss       : 0.9854948105812072
# 2025-11-27 18:36:27,925 -     val_AP_50      : 0.1222
# 2025-11-27 18:36:27,925 -     val_AP_75      : 0.0134
# 2025-11-27 18:36:27,925 -     val_IOU        : 0.18195125377774238
# 2025-11-27 18:50:59,803 -     epoch          : 9
# 2025-11-27 18:50:59,806 -     loss           : 1.0475226998329163
# 2025-11-27 18:50:59,806 -     grad_norm      : 0.999633709192276
# 2025-11-27 18:50:59,807 -     val_loss       : 1.0263184066772462
# 2025-11-27 18:50:59,807 -     val_AP_50      : 0.116
# 2025-11-27 18:50:59,807 -     val_AP_75      : 0.0117
# 2025-11-27 18:50:59,808 -     val_IOU        : 0.18715479695796966
# 2025-11-27 19:05:29,421 -     epoch          : 10
# 2025-11-27 19:05:29,425 -     loss           : 1.0072358810901643
# 2025-11-27 19:05:29,425 -     grad_norm      : 0.9999995994567871
# 2025-11-27 19:05:29,426 -     val_loss       : 0.9848772292137146
# 2025-11-27 19:05:29,426 -     val_AP_50      : 0.1514
# 2025-11-27 19:05:29,427 -     val_AP_75      : 0.027
# 2025-11-27 19:05:29,427 -     val_IOU        : 0.19816110538840292
# 2025-11-27 19:19:58,989 -     epoch          : 11
# 2025-11-27 19:19:58,991 -     loss           : 0.9970186841487885
# 2025-11-27 19:19:58,992 -     grad_norm      : 0.9944188463687896
# 2025-11-27 19:19:58,992 -     val_loss       : 0.9683937425613404
# 2025-11-27 19:19:58,992 -     val_AP_50      : 0.1637
# 2025-11-27 19:19:58,993 -     val_AP_75      : 0.0278
# 2025-11-27 19:19:58,993 -     val_IOU        : 0.2137823839008808
# 2025-11-27 19:34:27,947 -     epoch          : 12
# 2025-11-27 19:34:27,950 -     loss           : 1.0188521873950958
# 2025-11-27 19:34:27,951 -     grad_norm      : 0.9903111553192139
# 2025-11-27 19:34:27,951 -     val_loss       : 0.9594565137863159
# 2025-11-27 19:34:27,951 -     val_AP_50      : 0.1278
# 2025-11-27 19:34:27,951 -     val_AP_75      : 0.0243
# 2025-11-27 19:34:27,952 -     val_IOU        : 0.1640750877559185
# 2025-11-27 19:48:49,967 -     epoch          : 13
# 2025-11-27 19:48:49,969 -     loss           : 1.0018929719924927
# 2025-11-27 19:48:49,970 -     grad_norm      : 0.9939414155483246
# 2025-11-27 19:48:49,970 -     val_loss       : 1.0025632364273072
# 2025-11-27 19:48:49,971 -     val_AP_50      : 0.1093
# 2025-11-27 19:48:49,972 -     val_AP_75      : 0.0178
# 2025-11-27 19:48:49,972 -     val_IOU        : 0.15210906512141228
# 2025-11-27 20:03:11,047 -     epoch          : 14
# 2025-11-27 20:03:11,050 -     loss           : 0.9463953602313996
# 2025-11-27 20:03:11,050 -     grad_norm      : 0.9999996256828309
# 2025-11-27 20:03:11,050 -     val_loss       : 1.0047593477249146
# 2025-11-27 20:03:11,051 -     val_AP_50      : 0.1143
# 2025-11-27 20:03:11,051 -     val_AP_75      : 0.0257
# 2025-11-27 20:03:11,052 -     val_IOU        : 0.14029304509311916
# 2025-11-27 20:17:33,472 -     epoch          : 15
# 2025-11-27 20:17:33,474 -     loss           : 0.8999019122123718
# 2025-11-27 20:17:33,475 -     grad_norm      : 0.9944292616844177
# 2025-11-27 20:17:33,475 -     val_loss       : 0.9382187168121338
# 2025-11-27 20:17:33,476 -     val_AP_50      : 0.1297
# 2025-11-27 20:17:33,476 -     val_AP_75      : 0.0276
# 2025-11-27 20:17:33,477 -     val_IOU        : 0.17312784016728403
# 2025-11-27 20:31:55,036 -     epoch          : 16
# 2025-11-27 20:31:55,038 -     loss           : 0.912573709487915
# 2025-11-27 20:31:55,039 -     grad_norm      : 0.9999995768070221
# 2025-11-27 20:31:55,039 -     val_loss       : 0.9031444314002991
# 2025-11-27 20:31:55,040 -     val_AP_50      : 0.1605
# 2025-11-27 20:31:55,040 -     val_AP_75      : 0.0409
# 2025-11-27 20:31:55,040 -     val_IOU        : 0.19289159172177314
# 2025-11-27 20:46:17,380 -     epoch          : 17
# 2025-11-27 20:46:17,382 -     loss           : 0.8798777842521668
# 2025-11-27 20:46:17,383 -     grad_norm      : 0.9999996626377106
# 2025-11-27 20:46:17,384 -     val_loss       : 0.8764237204551697
# 2025-11-27 20:46:17,384 -     val_AP_50      : 0.1935
# 2025-11-27 20:46:17,385 -     val_AP_75      : 0.0539
# 2025-11-27 20:46:17,385 -     val_IOU        : 0.21837997553944588
# 2025-11-27 21:00:51,403 -     epoch          : 18
# 2025-11-27 21:00:51,407 -     loss           : 0.8725723612308502
# 2025-11-27 21:00:51,407 -     grad_norm      : 0.9999996364116669
# 2025-11-27 21:00:51,408 -     val_loss       : 0.8293707462310791
# 2025-11-27 21:00:51,408 -     val_AP_50      : 0.2316
# 2025-11-27 21:00:51,408 -     val_AP_75      : 0.0688
# 2025-11-27 21:00:51,409 -     val_IOU        : 0.24992447664737702
# 2025-11-27 21:15:20,984 -     epoch          : 19
# 2025-11-27 21:15:20,986 -     loss           : 0.8531698298454284
# 2025-11-27 21:15:20,987 -     grad_norm      : 0.9999996471405029
# 2025-11-27 21:15:20,987 -     val_loss       : 0.8174456874847412
# 2025-11-27 21:15:20,989 -     val_AP_50      : 0.2551
# 2025-11-27 21:15:20,990 -     val_AP_75      : 0.0731
# 2025-11-27 21:15:20,990 -     val_IOU        : 0.26159055334329606
# 2025-11-27 21:29:50,214 -     epoch          : 20
# 2025-11-27 21:29:50,217 -     loss           : 0.8532952880859375
# 2025-11-27 21:29:50,217 -     grad_norm      : 0.9954104840755462
# 2025-11-27 21:29:50,218 -     val_loss       : 0.8470484788894653
# 2025-11-27 21:29:50,218 -     val_AP_50      : 0.2357
# 2025-11-27 21:29:50,219 -     val_AP_75      : 0.0731
# 2025-11-27 21:29:50,219 -     val_IOU        : 0.24725354154109955
# 2025-11-27 21:44:12,077 -     epoch          : 21
# 2025-11-27 21:44:12,080 -     loss           : 0.8613398849964142
# 2025-11-27 21:44:12,080 -     grad_norm      : 0.9999996745586395
# 2025-11-27 21:44:12,081 -     val_loss       : 0.7852128999233245
# 2025-11-27 21:44:12,081 -     val_AP_50      : 0.2739
# 2025-11-27 21:44:12,081 -     val_AP_75      : 0.0879
# 2025-11-27 21:44:12,082 -     val_IOU        : 0.2835330608010292
# 2025-11-27 21:58:41,734 -     epoch          : 22
# 2025-11-27 21:58:41,736 -     loss           : 0.7690279996395111
# 2025-11-27 21:58:41,736 -     grad_norm      : 0.9999997615814209
# 2025-11-27 21:58:41,737 -     val_loss       : 0.767804935836792
# 2025-11-27 21:58:41,737 -     val_AP_50      : 0.2908
# 2025-11-27 21:58:41,737 -     val_AP_75      : 0.092
# 2025-11-27 21:58:41,738 -     val_IOU        : 0.289325159573555
# 2025-11-27 22:13:11,179 -     epoch          : 23
# 2025-11-27 22:13:11,181 -     loss           : 0.8079931819438935
# 2025-11-27 22:13:11,182 -     grad_norm      : 0.9999997019767761
# 2025-11-27 22:13:11,182 -     val_loss       : 0.73928566198349
# 2025-11-27 22:13:11,182 -     val_AP_50      : 0.3106
# 2025-11-27 22:13:11,183 -     val_AP_75      : 0.1003
# 2025-11-27 22:13:11,183 -     val_IOU        : 0.3113629511833191
# 2025-11-27 22:27:40,977 -     epoch          : 24
# 2025-11-27 22:27:40,980 -     loss           : 0.7692137789726258
# 2025-11-27 22:27:40,980 -     grad_norm      : 0.9999996984004974
# 2025-11-27 22:27:40,981 -     val_loss       : 0.7578763781547546
# 2025-11-27 22:27:40,981 -     val_AP_50      : 0.3372
# 2025-11-27 22:27:40,981 -     val_AP_75      : 0.1117
# 2025-11-27 22:27:40,982 -     val_IOU        : 0.32966832984685895
# 2025-11-27 22:42:08,974 -     epoch          : 25
# 2025-11-27 22:42:08,978 -     loss           : 0.7504866564273834
# 2025-11-27 22:42:08,978 -     grad_norm      : 0.9999996638298034
# 2025-11-27 22:42:08,978 -     val_loss       : 0.6895245293140412
# 2025-11-27 22:42:08,979 -     val_AP_50      : 0.3719
# 2025-11-27 22:42:08,979 -     val_AP_75      : 0.1243
# 2025-11-27 22:42:08,980 -     val_IOU        : 0.3581409662246704
# 2025-11-27 22:56:37,586 -     epoch          : 26
# 2025-11-27 22:56:37,589 -     loss           : 0.7467341494560241
# 2025-11-27 22:56:37,589 -     grad_norm      : 0.999999680519104
# 2025-11-27 22:56:37,590 -     val_loss       : 0.7087797777175904
# 2025-11-27 22:56:37,590 -     val_AP_50      : 0.3165
# 2025-11-27 22:56:37,590 -     val_AP_75      : 0.1144
# 2025-11-27 22:56:37,591 -     val_IOU        : 0.3097095825791359
# 2025-11-27 23:11:02,822 -     epoch          : 27
# 2025-11-27 23:11:02,825 -     loss           : 0.7089474010467529
# 2025-11-27 23:11:02,826 -     grad_norm      : 0.9999996018409729
# 2025-11-27 23:11:02,826 -     val_loss       : 0.6739611184597015
# 2025-11-27 23:11:02,827 -     val_AP_50      : 0.3602
# 2025-11-27 23:11:02,827 -     val_AP_75      : 0.1422
# 2025-11-27 23:11:02,828 -     val_IOU        : 0.3423527501106262
# 2025-11-27 23:25:23,933 -     epoch          : 28
# 2025-11-27 23:25:23,936 -     loss           : 0.6806860733032226
# 2025-11-27 23:25:23,936 -     grad_norm      : 0.9999997246265412
# 2025-11-27 23:25:23,937 -     val_loss       : 0.6788360905647278
# 2025-11-27 23:25:23,937 -     val_AP_50      : 0.3462
# 2025-11-27 23:25:23,938 -     val_AP_75      : 0.1387
# 2025-11-27 23:25:23,938 -     val_IOU        : 0.330845751452446
# 2025-11-27 23:39:45,551 -     epoch          : 29
# 2025-11-27 23:39:45,554 -     loss           : 0.6717722892761231
# 2025-11-27 23:39:45,554 -     grad_norm      : 0.9999997115135193
# 2025-11-27 23:39:45,555 -     val_loss       : 0.6322207354068756
# 2025-11-27 23:39:45,555 -     val_AP_50      : 0.4003
# 2025-11-27 23:39:45,556 -     val_AP_75      : 0.1572
# 2025-11-27 23:39:45,556 -     val_IOU        : 0.37595112917423246
# 2025-11-27 23:54:14,864 -     epoch          : 30
# 2025-11-27 23:54:14,867 -     loss           : 0.6573376673460006
# 2025-11-27 23:54:14,868 -     grad_norm      : 0.9999997591972352
# 2025-11-27 23:54:14,868 -     val_loss       : 0.6113288702964783
# 2025-11-27 23:54:14,869 -     val_AP_50      : 0.4603
# 2025-11-27 23:54:14,869 -     val_AP_75      : 0.1944
# 2025-11-27 23:54:14,869 -     val_IOU        : 0.4205016803741455
# 2025-11-28 00:08:45,357 -     epoch          : 31
# 2025-11-28 00:08:45,359 -     loss           : 0.6321183705329895
# 2025-11-28 00:08:45,360 -     grad_norm      : 0.9999996709823609
# 2025-11-28 00:08:45,360 -     val_loss       : 0.6038130114078522
# 2025-11-28 00:08:45,361 -     val_AP_50      : 0.4078
# 2025-11-28 00:08:45,361 -     val_AP_75      : 0.1752
# 2025-11-28 00:08:45,361 -     val_IOU        : 0.37906815235614777
# 2025-11-28 00:23:06,928 -     epoch          : 32
# 2025-11-28 00:23:06,931 -     loss           : 0.6244416618347168
# 2025-11-28 00:23:06,931 -     grad_norm      : 0.9999996984004974
# 2025-11-28 00:23:06,932 -     val_loss       : 0.5788795916080475
# 2025-11-28 00:23:06,932 -     val_AP_50      : 0.4598
# 2025-11-28 00:23:06,935 -     val_AP_75      : 0.196
# 2025-11-28 00:23:06,935 -     val_IOU        : 0.4126450511932373
# 2025-11-28 00:37:29,060 -     epoch          : 33
# 2025-11-28 00:37:29,062 -     loss           : 0.6173327136039733
# 2025-11-28 00:37:29,062 -     grad_norm      : 0.9999997103214264
# 2025-11-28 00:37:29,063 -     val_loss       : 0.6205468731880188
# 2025-11-28 00:37:29,063 -     val_AP_50      : 0.3892
# 2025-11-28 00:37:29,063 -     val_AP_75      : 0.1727
# 2025-11-28 00:37:29,064 -     val_IOU        : 0.3565042799949646
# 2025-11-28 00:51:51,360 -     epoch          : 34
# 2025-11-28 00:51:51,363 -     loss           : 0.5944971692562103
# 2025-11-28 00:51:51,363 -     grad_norm      : 0.999999669790268
# 2025-11-28 00:51:51,364 -     val_loss       : 0.5911910204887391
# 2025-11-28 00:51:51,364 -     val_AP_50      : 0.4222
# 2025-11-28 00:51:51,365 -     val_AP_75      : 0.183
# 2025-11-28 00:51:51,365 -     val_IOU        : 0.3905540284633636
# 2025-11-28 01:06:12,583 -     epoch          : 35
# 2025-11-28 01:06:12,586 -     loss           : 0.6152457845211029
# 2025-11-28 01:06:12,587 -     grad_norm      : 0.9999997186660766
# 2025-11-28 01:06:12,587 -     val_loss       : 0.5962148813247681
# 2025-11-28 01:06:12,587 -     val_AP_50      : 0.4086
# 2025-11-28 01:06:12,588 -     val_AP_75      : 0.1917
# 2025-11-28 01:06:12,588 -     val_IOU        : 0.3793985699892044
# 2025-11-28 01:20:37,810 -     epoch          : 36
# 2025-11-28 01:20:37,813 -     loss           : 0.5481866407394409
# 2025-11-28 01:20:37,813 -     grad_norm      : 0.9999997329711914
# 2025-11-28 01:20:37,814 -     val_loss       : 0.5458302227973938
# 2025-11-28 01:20:37,814 -     val_AP_50      : 0.5072
# 2025-11-28 01:20:37,815 -     val_AP_75      : 0.2444
# 2025-11-28 01:20:37,815 -     val_IOU        : 0.4523603039264679
# 2025-11-28 01:35:06,994 -     epoch          : 37
# 2025-11-28 01:35:06,998 -     loss           : 0.5602675241231918
# 2025-11-28 01:35:06,998 -     grad_norm      : 0.9999968373775482
# 2025-11-28 01:35:06,999 -     val_loss       : 0.5851296034812927
# 2025-11-28 01:35:06,999 -     val_AP_50      : 0.419
# 2025-11-28 01:35:07,000 -     val_AP_75      : 0.1842
# 2025-11-28 01:35:07,000 -     val_IOU        : 0.38715886595249177
# 2025-11-28 01:49:29,068 -     epoch          : 38
# 2025-11-28 01:49:29,070 -     loss           : 0.5385747593641281
# 2025-11-28 01:49:29,071 -     grad_norm      : 0.9999996769428253
# 2025-11-28 01:49:29,072 -     val_loss       : 0.5148738077163696
# 2025-11-28 01:49:29,072 -     val_AP_50      : 0.5137
# 2025-11-28 01:49:29,073 -     val_AP_75      : 0.2476
# 2025-11-28 01:49:29,073 -     val_IOU        : 0.45305702946186066
# 2025-11-28 02:03:58,413 -     epoch          : 39
# 2025-11-28 02:03:58,416 -     loss           : 0.5275533890724182
# 2025-11-28 02:03:58,417 -     grad_norm      : 0.9999997413158417
# 2025-11-28 02:03:58,417 -     val_loss       : 0.5490800288677216
# 2025-11-28 02:03:58,418 -     val_AP_50      : 0.4574
# 2025-11-28 02:03:58,419 -     val_AP_75      : 0.2049
# 2025-11-28 02:03:58,419 -     val_IOU        : 0.4127289763689041
# 2025-11-28 02:18:19,664 -     epoch          : 40
# 2025-11-28 02:18:19,667 -     loss           : 0.5337360942363739
# 2025-11-28 02:18:19,668 -     grad_norm      : 0.999999715089798
# 2025-11-28 02:18:19,668 -     val_loss       : 0.5017393492221832
# 2025-11-28 02:18:19,668 -     val_AP_50      : 0.5286
# 2025-11-28 02:18:19,669 -     val_AP_75      : 0.2767
# 2025-11-28 02:18:19,669 -     val_IOU        : 0.4663077390432358
# 2025-11-28 02:32:49,197 -     epoch          : 41
# 2025-11-28 02:32:49,200 -     loss           : 0.5196029204130173
# 2025-11-28 02:32:49,200 -     grad_norm      : 0.9999996912479401
# 2025-11-28 02:32:49,201 -     val_loss       : 0.5016699357032776
# 2025-11-28 02:32:49,201 -     val_AP_50      : 0.5075
# 2025-11-28 02:32:49,201 -     val_AP_75      : 0.2676
# 2025-11-28 02:32:49,202 -     val_IOU        : 0.4474786064147949
# ```

# %% [markdown]
# Для сравнения я возьму результаты из статьи в силу сложной воспроизводимости экспериментов `Sida` (она основана на LLM, которая пытается определить класс, а по внутренним её представлениям уже строятся маски) - модель из статьи `SidSet`:
#
# | Model | Segmentation IOU | Classification Accuracy |
# |-------|------------------|-------------------------|
# | Sida  | 0.438            | 93.5%                   |
# | VSSD  | 0.466            | 83.7%                   |

# %% [markdown]
# Всего за 9 с половиной часов модель `VSSD` получила результат по сегментации лучше, чем `Sida`, без подбора гиперпараметров и прочих ухищрений. При этом стоит отметить, что использовалась самая большая из представленных моделей `VSSD` (она же `base`).
#
# Несмотря на успех в сегментации, точность классификации у `VSSD` ниже, чем у `Sida`. Скорее всего, это с банальным недоучиванием модели, так как для `SIDA` была использована большая предобученная LLM модель с визуальным вводом. Успех же в сегментации можно обосновать тем, что для регионов, в которых произошли модификации, очень важно их окружение со всех сторон, за счет чего `VSSD` и получает приемущество за счет своей архитектуры.

# %% [markdown]
# Стоит дополнительно отметить, что для сегментации была использована лишь часть с модификациями, без сгенерированных и реальных картинок. Вполне возможно, что их добавление в тренировочный набор позволит еще больше повысить качество сегментации.

# %% [markdown]
# # Решение домашнего задания #8

# %%
import ast
from concurrent.futures import ThreadPoolExecutor
import os
from typing import Literal
import re

import kagglehub
from transformers import pipeline

import pandas as pd
import numpy as np
from tabulate import tabulate
from tqdm import tqdm

import swifter

# %%
HARD_PREDICTION_PROMPT = """Classify the following BBC news article into one of the following categories: {categories}.

Article:
{article}

What is the most appropriate category for this article? Write the name of the category only, without any additional text or explanation. Do not use any punctuation marks."""

SOFT_PREDICTION_PROMPT = """Given the following BBC news article, estimate the likelihood (in percentage) that it belongs to each of the following categories: {categories}. Ensure that the total adds up to 100%.

Article:
{article}

What are the predicted probabilities for each category? Write the probabilities in the following format:
Category1: <probabilty1>, Category2: <probabilty2>, Category3: <probabilty3>, ...
Do not use any additional text or explanations. Ensure that the percentages are whole numbers and sum to 100%."""

# %%
# path = kagglehub.dataset_download("adityajn105/flickr8k")                              # C:\\Users\\setday\\.cache\\kagglehub\\datasets\\adityajn105\\flickr8k\\versions\\1
# path = kagglehub.dataset_download("alfathterry/bbc-full-text-document-classification") # C:\\Users\\setday\\.cache\\kagglehub\\datasets\\alfathterry\\bbc-full-text-document-classification\\versions\\1

# %%
# path = kagglehub.dataset_download("alfathterry/bbc-full-text-document-classification")
path = "C:\\Users\\setday\\.cache\\kagglehub\\datasets\\alfathterry\\bbc-full-text-document-classification\\versions\\1"

data = pd.read_csv(path + "\\bbc_data.csv")
categories = data["labels"].unique()

# %%
data["soft_query"] = data["data"].apply(lambda data: f'User: {SOFT_PREDICTION_PROMPT.format(categories=", ".join(categories), article=data)}\n\nModel: Article category probabilities are:')
data["hard_query"] = data["data"].apply(lambda data: f'User: {HARD_PREDICTION_PROMPT.format(categories=", ".join(categories), article=data)}\n\nModel: Article category is:')

# %%
data
# Out:
#                                                    data         labels  \
# 0     Musicians to tackle US red tape  Musicians gro...  entertainment
# 1     U2s desire to be number one  U2, who have won ...  entertainment
# 2     Rocker Doherty in on-stage fight  Rock singer ...  entertainment
# 3     Snicket tops US box office chart  The film ada...  entertainment
# 4     Oceans Twelve raids box office  Oceans Twelve,...  entertainment
# ...                                                 ...            ...
# 2220  Warning over Windows Word files  Writing a Mic...           tech
# 2221  Fast lifts rise into record books  Two high-sp...           tech
# 2222  Nintendo adds media playing to DS  Nintendo is...           tech
# 2223  Fast moving phone viruses appear  Security fir...           tech
# 2224  Hacker threat to Apples iTunes  Users of Apple...           tech
#
#                                              hard_query  \
# 0     User: Classify the following BBC news article ...
# 1     User: Classify the following BBC news article ...
# 2     User: Classify the following BBC news article ...
# 3     User: Classify the following BBC news article ...
# 4     User: Classify the following BBC news article ...
# ...                                                 ...
# 2220  User: Classify the following BBC news article ...
# 2221  User: Classify the following BBC news article ...
# 2222  User: Classify the following BBC news article ...
# 2223  User: Classify the following BBC news article ...
# 2224  User: Classify the following BBC news article ...
#
#                                              soft_query   hard_answers
# 0     User: Given the following BBC news article, es...  entertainment
# 1     User: Given the following BBC news article, es...  entertainment
# 2     User: Given the following BBC news article, es...  entertainment
# 3     User: Given the following BBC news article, es...  entertainment
# 4     User: Given the following BBC news article, es...  entertainment
# ...                                                 ...            ...
# 2220  User: Given the following BBC news article, es...       business
# 2221  User: Given the following BBC news article, es...  entertainment
# 2222  User: Given the following BBC news article, es...  entertainment
# 2223  User: Given the following BBC news article, es...  entertainment
# 2224  User: Given the following BBC news article, es...  entertainment
#
# [2225 rows x 5 columns]

# %%
pipe = pipeline("text-generation", model="meta-llama/Llama-3.2-1B", device='cuda', max_new_tokens=30)

# %%
def extract_category(texts: list[str], categories: list[str]):
    texts = [text.lower() for text in texts]
    categories = [category.lower() for category in categories]

    extracted = []
    for text in texts:
        for category in categories:
            if category in text:
                extracted.append(category)
                break
        else:
            extracted.append('none')
    return extracted

def get_categories(queries: list[str], categories: list[str], batch_size=32):
    results = []
    for i in tqdm(range(0, len(queries), batch_size)):
        batch_data = queries.iloc[i:i + batch_size].to_list()
        outs = pipe.predict(batch_data)
        outs = [
            out[0]["generated_text"][len(query):]
            for out, query in zip(outs, batch_data)
        ]
        results.extend(extract_category(outs, categories))
    return results

# %%
data["hard_answers"] = get_categories(data["hard_query"], categories)
# Out:
#   0%|          | 0/70 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|▏         | 1/70 [00:43<50:02, 43.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 2/70 [01:20<45:05, 39.78s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 3/70 [01:59<43:48, 39.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 4/70 [02:51<48:50, 44.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 5/70 [03:56<55:57, 51.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▊         | 6/70 [05:04<1:01:11, 57.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 7/70 [06:06<1:01:46, 58.84s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█▏        | 8/70 [07:09<1:02:20, 60.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 9/70 [08:11<1:01:50, 60.83s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 10/70 [09:29<1:05:55, 65.92s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 11/70 [10:25<1:01:46, 62.82s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 12/70 [11:52<1:08:06, 70.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▊        | 13/70 [12:54<1:04:23, 67.77s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 14/70 [14:09<1:05:23, 70.07s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██▏       | 15/70 [15:12<1:02:05, 67.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 16/70 [16:23<1:01:51, 68.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 17/70 [17:24<58:44, 66.49s/it]  Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 18/70 [18:29<57:09, 65.95s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 19/70 [19:30<54:52, 64.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▊       | 20/70 [20:30<52:41, 63.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# ...
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 63/70 [1:57:41<12:56, 110.98s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████▏| 64/70 [1:59:30<11:01, 110.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 65/70 [2:01:05<08:47, 105.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 66/70 [2:02:49<07:01, 105.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 67/70 [2:04:31<05:12, 104.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 68/70 [2:06:21<03:31, 105.91s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▊| 69/70 [2:07:43<01:38, 98.92s/it] Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|██████████| 70/70 [2:08:18<00:00, 109.98s/it]

# %%
data["hard_answers"].value_counts()
# Out:
# hard_answers
# entertainment    1611
# business          323
# sport             174
# politics           85
# tech               30
# none                2
# Name: count, dtype: int64

# %%
data = pd.read_csv("tst.csv")

# %%
def get_categories_probs(queries: list[str], categories: list[str], batch_size=64):
    results = []
    for i in tqdm(range(0, len(queries), batch_size)):
        batch_data = queries.iloc[i:i + batch_size].to_list()
        outs = pipe.predict(batch_data)
        outs = [
            out[0]["generated_text"][len(query):]
            for out, query in zip(outs, batch_data)
        ]
        results.extend(outs)
    return results

def extract_categories_probs(answers: list[str], categories: list[str]):
    splits = [
        a.lower()\
            .replace("%", "")\
                .replace("=", " ")\
                    .replace(":", " ")\
                        .replace("(", "")\
                            .replace(")", "")\
                                .replace("\n", " | ")\
                                    .replace(",", " ")\
                                        .replace(". ", " ")\
                                            .split()\
        for a in answers
    ]
    extracted = [
        {
            category: float(proba)
            for category, proba in zip(s, s[1:])
            if category in categories and (proba.isdigit() or re.match(r'^-?\d+(?:\.\d*)$', proba) is not None)
        }
        for s in splits
    ]
    filtered = [
        e if all([category in e for category in categories])
        else {}
        for e in extracted
    ]
    return [
        {
            category: float(proba) / sum(f.values())
            for category, proba in f.items()
        }
        for f in filtered
    ]

data["soft_probs"] = extract_categories_probs(get_categories_probs(data["soft_query"], categories), categories)

# %%
data.to_csv("123.csv")

# %%
data
# Out:
#                                                    data         labels  \
# 0     Musicians to tackle US red tape  Musicians gro...  entertainment
# 1     U2s desire to be number one  U2, who have won ...  entertainment
# 2     Rocker Doherty in on-stage fight  Rock singer ...  entertainment
# 3     Snicket tops US box office chart  The film ada...  entertainment
# 4     Oceans Twelve raids box office  Oceans Twelve,...  entertainment
# ...                                                 ...            ...
# 2220  Warning over Windows Word files  Writing a Mic...           tech
# 2221  Fast lifts rise into record books  Two high-sp...           tech
# 2222  Nintendo adds media playing to DS  Nintendo is...           tech
# 2223  Fast moving phone viruses appear  Security fir...           tech
# 2224  Hacker threat to Apples iTunes  Users of Apple...           tech
#
#                                              hard_query  \
# 0     User: Classify the following BBC news article ...
# 1     User: Classify the following BBC news article ...
# 2     User: Classify the following BBC news article ...
# 3     User: Classify the following BBC news article ...
# 4     User: Classify the following BBC news article ...
# ...                                                 ...
# 2220  User: Classify the following BBC news article ...
# 2221  User: Classify the following BBC news article ...
# 2222  User: Classify the following BBC news article ...
# 2223  User: Classify the following BBC news article ...
# 2224  User: Classify the following BBC news article ...
#
#                                              soft_query   hard_answers
# 0     User: Given the following BBC news article, es...  entertainment
# 1     User: Given the following BBC news article, es...  entertainment
# 2     User: Given the following BBC news article, es...  entertainment
# 3     User: Given the following BBC news article, es...  entertainment
# 4     User: Given the following BBC news article, es...  entertainment
# ...                                                 ...            ...
# 2220  User: Given the following BBC news article, es...       business
# 2221  User: Given the following BBC news article, es...  entertainment
# 2222  User: Given the following BBC news article, es...  entertainment
# 2223  User: Given the following BBC news article, es...  entertainment
# 2224  User: Given the following BBC news article, es...  entertainment
#
# [2225 rows x 5 columns]
